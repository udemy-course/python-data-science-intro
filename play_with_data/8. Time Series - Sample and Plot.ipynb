# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
t_range = pd.date_range('2016-01-01', '2016-12-31')

# %%
t_range
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10',
#                ...
#                '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25',
#                '2016-12-26', '2016-12-27', '2016-12-28', '2016-12-29',
#                '2016-12-30', '2016-12-31'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
s = Series(np.random.rand(len(t_range)), index=t_range)

# %%
s['2016-01'].mean()
# Out:
# 0.47250451193211707

# %%
s_month = s.resample('M').mean()

# %%
s_month
# Out:
# 2016-01-31    0.472505
# 2016-02-29    0.451652
# 2016-03-31    0.473549
# 2016-04-30    0.468149
# 2016-05-31    0.475951
# 2016-06-30    0.511000
# 2016-07-31    0.589024
# 2016-08-31    0.421759
# 2016-09-30    0.448688
# 2016-10-31    0.467448
# 2016-11-30    0.467803
# 2016-12-31    0.467738
# Freq: M, dtype: float64

# %%
s_hour = s.resample('H').fill()

# %%
s_hour
# Out:
# 2016-01-01 00:00:00    0.301210
# 2016-01-01 01:00:00    0.064187
# 2016-01-01 02:00:00    0.064187
# 2016-01-01 03:00:00    0.064187
# 2016-01-01 04:00:00    0.064187
# 2016-01-01 05:00:00    0.064187
# 2016-01-01 06:00:00    0.064187
# 2016-01-01 07:00:00    0.064187
# 2016-01-01 08:00:00    0.064187
# 2016-01-01 09:00:00    0.064187
# 2016-01-01 10:00:00    0.064187
# 2016-01-01 11:00:00    0.064187
# 2016-01-01 12:00:00    0.064187
# 2016-01-01 13:00:00    0.064187
# 2016-01-01 14:00:00    0.064187
# 2016-01-01 15:00:00    0.064187
# 2016-01-01 16:00:00    0.064187
# 2016-01-01 17:00:00    0.064187
# 2016-01-01 18:00:00    0.064187
# 2016-01-01 19:00:00    0.064187
# 2016-01-01 20:00:00    0.064187
# 2016-01-01 21:00:00    0.064187
# 2016-01-01 22:00:00    0.064187
# 2016-01-01 23:00:00    0.064187
# 2016-01-02 00:00:00    0.064187
# 2016-01-02 01:00:00    0.306261
# 2016-01-02 02:00:00    0.306261
# 2016-01-02 03:00:00    0.306261
# 2016-01-02 04:00:00    0.306261
# ...

# %%
s[0]
# Out:
# 0.30120961315929373

# %%
s[1]
# Out:
# 0.064187462720172062

# %%
s.plot()

# %%
# %matplotlib inline

# %%
s.plot()

# %%
s_month.plot()
