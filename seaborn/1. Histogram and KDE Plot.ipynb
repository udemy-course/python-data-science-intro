# %%
# basic
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# seaborn
import seaborn as sns

# %%
s = Series(np.random.randn(1000))

# %%
s.plot(kind='hist')

# %%
s.plot(kind='kde')

# %%
plt.hist(s)
# Out:
# (array([   3.,   25.,   94.,  210.,  252.,  244.,  118.,   44.,    7.,    3.]),
#  array([-3.30027796, -2.60670345, -1.91312894, -1.21955443, -0.52597992,
#          0.16759459,  0.8611691 ,  1.55474361,  2.24831812,  2.94189263,
#          3.63546714]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # seaborn

# %%
sns.distplot(s,color='r', bins=30)

# %%
sns.kdeplot(s, color='r', shade=True)
