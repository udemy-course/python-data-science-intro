# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = DataFrame(np.random.randint(1, 10, 40).reshape(10,4), columns=['A','B','C','D'])

# %%
df
# Out:
#    A  B  C  D
# 0  5  7  6  7
# 1  5  3  8  7
# 2  7  2  9  8
# 3  9  2  4  9
# 4  7  9  3  4
# 5  6  5  4  8
# 6  1  4  5  4
# 7  7  1  9  1
# 8  7  7  2  8
# 9  9  4  6  2

# %%
df.plot()

# %%
for i in df.index:
    df.loc[i].plot(label=str(i))
plt.legend()

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh')

# %%
df.plot(kind='bar', stacked=True)

# %%
df.plot(kind='area')

# %%
df['A'].plot()
